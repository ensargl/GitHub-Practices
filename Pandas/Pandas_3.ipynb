# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # **DataFrame’lerde Eleman Seçim İşlemleri**

# %%
np.random.seed(101)
df = pd.DataFrame(data=np.random.randn(5,6),index="A B C D E".split(),columns=["C1 C2 C3 C4 C5 C6".split()])

# %%
df
# Out:
#          C1        C2        C3        C4        C5        C6
# A  2.706850  0.628133  0.907969  0.503826  0.651118 -0.319318
# B -0.848077  0.605965 -2.018168  0.740122  0.528813 -0.589001
# C  0.188695 -0.758872 -0.933237  0.955057  0.190794  1.978757
# D  2.605967  0.683509  0.302665  1.693723 -1.706086 -1.159119
# E -0.134841  0.390528  0.166905  0.184502  0.807706  0.072960

# %%
df["C1"]
# Out:
#          C1
# A  2.706850
# B -0.848077
# C  0.188695
# D  2.605967
# E -0.134841

# %%
df[["C1"]]
# Out:
#          C1
# A  2.706850
# B -0.848077
# C  0.188695
# D  2.605967
# E -0.134841

# %%
df.C1
# Out:
#          C1
# A  2.706850
# B -0.848077
# C  0.188695
# D  2.605967
# E -0.134841

# %%
df["C1"].values # "C1" sütunundaki değerlere np.array dizisi formatında eriştik.
# Out:
# array([[ 2.70684984],
#        [-0.84807698],
#        [ 0.18869531],
#        [ 2.60596728],
#        [-0.13484072]])

# %%
df.C1.values  # "C1" sütunundaki değerlere np.array dizisi formatında eriştik.
# Out:
# array([[ 2.70684984],
#        [-0.84807698],
#        [ 0.18869531],
#        [ 2.60596728],
#        [-0.13484072]])

# %%
df[["C1"]][1:4]
# Out:
#          C1
# B -0.848077
# C  0.188695
# D  2.605967

# %% [markdown]
# # **İndeksleme ve Dilimleme (Slicing) İşlemleri**

# %%
df[1:4]
# Out:
#          C1        C2        C3        C4        C5        C6
# B -0.848077  0.605965 -2.018168  0.740122  0.528813 -0.589001
# C  0.188695 -0.758872 -0.933237  0.955057  0.190794  1.978757
# D  2.605967  0.683509  0.302665  1.693723 -1.706086 -1.159119

# %%
df.loc[["A","B","C"],]
# Out:
#          C1        C2        C3        C4        C5        C6
# A  2.706850  0.628133  0.907969  0.503826  0.651118 -0.319318
# B -0.848077  0.605965 -2.018168  0.740122  0.528813 -0.589001
# C  0.188695 -0.758872 -0.933237  0.955057  0.190794  1.978757

# %%
df.iloc[[1,2,3],]
# Out:
#          C1        C2        C3        C4        C5        C6
# B -0.848077  0.605965 -2.018168  0.740122  0.528813 -0.589001
# C  0.188695 -0.758872 -0.933237  0.955057  0.190794  1.978757
# D  2.605967  0.683509  0.302665  1.693723 -1.706086 -1.159119

# %%
# Örnek DF-2 
df2 = pd.DataFrame(data = np.random.randn(6,5), index="A B C D E F".split(), columns=["VAL1 VAL2 VAL3 VAL4 VAL5".split()])

# %%
df2
# Out:
#        VAL1      VAL2      VAL3      VAL4      VAL5
# A  0.638787  0.329646 -0.497104 -0.754070 -0.943406
# B  0.484752 -0.116773  1.901755  0.238127  1.996652
# C -0.993263  0.196800 -1.136645  0.000366  1.025984
# D -0.156598 -0.031579  0.649826  2.154846 -0.610259
# E -0.755325 -0.346419  0.147027 -0.479448  0.558769
# F  1.024810 -0.925874  1.862864 -1.133817  0.610478

# %%
df2.loc["E":"E",["VAL1","VAL3"]]
# Out:
#        VAL1      VAL3
# E -0.755325  0.147027

# %%
df2.loc[["E"],["VAL1","VAL3"]]
# Out:
#        VAL1      VAL3
# E -0.755325  0.147027

# %%
df2.iloc[4:5,:3:2]
# Out:
#        VAL1      VAL3
# E -0.755325  0.147027

# %%
df2.iloc[[-2],[0,2]]
# Out:
#        VAL1      VAL3
# E -0.755325  0.147027

# %% [markdown]
# # **loc[] ve iloc[] Yapıları**

# %%
# Örnek-3

np.random.seed(101)
np_array = np.random.randint(10 ,50 ,(10,5))

# %%
df3 = pd.DataFrame(data=np_array , index="A B C D E F G H I J".split() ,columns="VAL1 VAL2 VAL3 VAL4 VAL5".split())

# %%
df3
# Out:
#    VAL1  VAL2  VAL3  VAL4  VAL5
# A    41    21    27    16    33
# B    21    19    23    14    38
# C    10    15    22    39    29
# D    18    39    44    18    29
# E    20    22    41    33    10
# F    19    18    46    29    45
# G    38    17    20    49    48
# H    19    28    17    49    25
# I    10    22    27    21    25
# J    43    39    34    46    29

# %%
# Alıştırma-1

df3.loc[["C"],["VAL4"]] # DF formatında sonucu gördük.
# Out:
#    VAL4
# C    39

# %%
df3.iloc[[2],[3]]  # DF formatında sonucu gördük.
# Out:
#    VAL4
# C    39

# %%
df3.loc["C","VAL4"] # Numpy int formatında sonucu gördük.
# Out:
# 39

# %%
df3.iloc[2,3] # Numpy int formatında sonucu gördük.
# Out:
# 39

# %%
df3.loc["C":"C","VAL4":"VAL4"]
# Out:
#    VAL4
# C    39

# %%
df3.iloc[2:3,3:4]
# Out:
#    VAL4
# C    39

# %%
df3
# Out:
#    VAL1  VAL2  VAL3  VAL4  VAL5
# A    41    21    27    16    33
# B    21    19    23    14    38
# C    10    15    22    39    29
# D    18    39    44    18    29
# E    20    22    41    33    10
# F    19    18    46    29    45
# G    38    17    20    49    48
# H    19    28    17    49    25
# I    10    22    27    21    25
# J    43    39    34    46    29

# %%
# Alıştırma-2

df3.iloc[[2,3,4,5,6],[2]]
# Out:
#    VAL3
# C    22
# D    44
# E    41
# F    46
# G    20

# %%
df3.iloc[2:7,2:3]
# Out:
#    VAL3
# C    22
# D    44
# E    41
# F    46
# G    20

# %%
df3.iloc[2:7,2]
# Out:
# C    22
# D    44
# E    41
# F    46
# G    20
# Name: VAL3, dtype: int32

# %%
df3.iloc[[2,3,4,5,6],2]
# Out:
# C    22
# D    44
# E    41
# F    46
# G    20
# Name: VAL3, dtype: int32

# %%
df3.loc["C":"G","VAL3":"VAL3"]
# Out:
#    VAL3
# C    22
# D    44
# E    41
# F    46
# G    20

# %%
df3.loc[["C","D","E","F","G"],["VAL3"]]
# Out:
#    VAL3
# C    22
# D    44
# E    41
# F    46
# G    20

# %%
# Alıştırma-2.1

df3.loc["C":"G","VAL3"]
# Out:
# C    22
# D    44
# E    41
# F    46
# G    20
# Name: VAL3, dtype: int32

# %%
# Alıştırma-2.2

df3.loc[["C","D","E","F","G"],"VAL3"]
# Out:
# C    22
# D    44
# E    41
# F    46
# G    20
# Name: VAL3, dtype: int32

# %%
df3
# Out:
#    VAL1  VAL2  VAL3  VAL4  VAL5
# A    41    21    27    16    33
# B    21    19    23    14    38
# C    10    15    22    39    29
# D    18    39    44    18    29
# E    20    22    41    33    10
# F    19    18    46    29    45
# G    38    17    20    49    48
# H    19    28    17    49    25
# I    10    22    27    21    25
# J    43    39    34    46    29

# %%
# Alıştırma-3

df3.loc["C":"H","VAL2":"VAL4"]
# Out:
#    VAL2  VAL3  VAL4
# C    15    22    39
# D    39    44    18
# E    22    41    33
# F    18    46    29
# G    17    20    49
# H    28    17    49

# %%
df3.loc[["C","D","E","F","G","H"],["VAL2","VAL3","VAL4"]]
# Out:
#    VAL2  VAL3  VAL4
# C    15    22    39
# D    39    44    18
# E    22    41    33
# F    18    46    29
# G    17    20    49
# H    28    17    49

# %%
df3.iloc[2:8,1:4]
# Out:
#    VAL2  VAL3  VAL4
# C    15    22    39
# D    39    44    18
# E    22    41    33
# F    18    46    29
# G    17    20    49
# H    28    17    49

# %%
df3.iloc[[2,3,4,5,6,7],[1,2,3]]
# Out:
#    VAL2  VAL3  VAL4
# C    15    22    39
# D    39    44    18
# E    22    41    33
# F    18    46    29
# G    17    20    49
# H    28    17    49

# %%
# Alıştırma-3.1

df3.iloc[[2,3,4,5,6,7],[1,2,3]].iloc[2:4,1:2] # Kombine iloc[] kullanımı...
# Out:
#    VAL3
# E    41
# F    46

# %%
df3.iloc[[4,5],[2]]
# Out:
#    VAL3
# E    41
# F    46

# %% [markdown]
# # **DataFrame’lerde Koşullu İşlemler İle Elaman Seçimi**

# %%
df3
# Out:
#    VAL1  VAL2  VAL3  VAL4  VAL5
# A    41    21    27    16    33
# B    21    19    23    14    38
# C    10    15    22    39    29
# D    18    39    44    18    29
# E    20    22    41    33    10
# F    19    18    46    29    45
# G    38    17    20    49    48
# H    19    28    17    49    25
# I    10    22    27    21    25
# J    43    39    34    46    29

# %%
# Örnek-1

df3>30 # df3'te 30'dan büyük değerlerin bool tipte gösterimi...
# Out:
#     VAL1   VAL2   VAL3   VAL4   VAL5
# A   True  False  False  False   True
# B  False  False  False  False   True
# C  False  False  False   True  False
# D  False   True   True  False  False
# E  False  False   True   True  False
# F  False  False   True  False   True
# G   True  False  False   True   True
# H  False  False  False   True  False
# I  False  False  False  False  False
# J   True   True   True   True  False

# %%
df3[df3>30]
# Out:
#    VAL1  VAL2  VAL3  VAL4  VAL5
# A  41.0   NaN   NaN   NaN  33.0
# B   NaN   NaN   NaN   NaN  38.0
# C   NaN   NaN   NaN  39.0   NaN
# D   NaN  39.0  44.0   NaN   NaN
# E   NaN   NaN  41.0  33.0   NaN
# F   NaN   NaN  46.0   NaN  45.0
# G  38.0   NaN   NaN  49.0  48.0
# H   NaN   NaN   NaN  49.0   NaN
# I   NaN   NaN   NaN   NaN   NaN
# J  43.0  39.0  34.0  46.0   NaN

# %%
df3["VAL5"] >30
# Out:
# A     True
# B     True
# C    False
# D    False
# E    False
# F     True
# G     True
# H    False
# I    False
# J    False
# Name: VAL5, dtype: bool

# %%
df3[df3["VAL5"] > 30]
# Out:
#    VAL1  VAL2  VAL3  VAL4  VAL5
# A    41    21    27    16    33
# B    21    19    23    14    38
# F    19    18    46    29    45
# G    38    17    20    49    48

# %%
df3[df3["VAL5"] > 30]["VAL5"] # df3 içerisinde df3 ün "VAL5" sütununda yer alan, 30 dan büyük değerlerin seri formatında gösterimi...
# Out:
# A    33
# B    38
# F    45
# G    48
# Name: VAL5, dtype: int32

# %%
df3[df3["VAL5"] > 30][["VAL5"]] # df3 içerisinde df3 ün "VAL5" sütununda yer alan, 30 dan büyük değerlerin DF formatında gösterimi...
# Out:
#    VAL5
# A    33
# B    38
# F    45
# G    48

# %%
df3
# Out:
#    VAL1  VAL2  VAL3  VAL4  VAL5
# A    41    21    27    16    33
# B    21    19    23    14    38
# C    10    15    22    39    29
# D    18    39    44    18    29
# E    20    22    41    33    10
# F    19    18    46    29    45
# G    38    17    20    49    48
# H    19    28    17    49    25
# I    10    22    27    21    25
# J    43    39    34    46    29

# %%
# Örnek-2

# df3'ün "VAL1" sütununda yer alan 15 ten küçük değerler ile "VAL5" sütununda yer alan 29 dan büyük ve eşit değerleri yeni bir df olarak gösteriniz...

# %%
df3[df3["VAL1"] <15]
# Out:
#    VAL1  VAL2  VAL3  VAL4  VAL5
# C    10    15    22    39    29
# I    10    22    27    21    25

# %%
df3[df3["VAL1"] <15][["VAL1"]]
# Out:
#    VAL1
# C    10
# I    10

# %%
df3_val1 = df3[df3["VAL1"] <15][["VAL1"]]

# %%
df3_val1
# Out:
#    VAL1
# C    10
# I    10

# %%
df3["VAL5"] >= 29
# Out:
# A     True
# B     True
# C     True
# D     True
# E    False
# F     True
# G     True
# H    False
# I    False
# J     True
# Name: VAL5, dtype: bool

# %%
df3[df3["VAL5"] >= 29]
# Out:
#    VAL1  VAL2  VAL3  VAL4  VAL5
# A    41    21    27    16    33
# B    21    19    23    14    38
# C    10    15    22    39    29
# D    18    39    44    18    29
# F    19    18    46    29    45
# G    38    17    20    49    48
# J    43    39    34    46    29

# %%
df3[df3["VAL5"] >= 29][["VAL5"]]
# Out:
#    VAL5
# A    33
# B    38
# C    29
# D    29
# F    45
# G    48
# J    29

# %%
df3_val5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[171], line 1
# ----> 1 df3_val5
#
# NameError: name 'df3_val5' is not defined

# %% [markdown]
# ### Birden Fazla Koşullu İşlemler

# %%
df3
# Out:
#    VAL1  VAL2  VAL3  VAL4  VAL5
# A    41    21    27    16    33
# B    21    19    23    14    38
# C    10    15    22    39    29
# D    18    39    44    18    29
# E    20    22    41    33    10
# F    19    18    46    29    45
# G    38    17    20    49    48
# H    19    28    17    49    25
# I    10    22    27    21    25
# J    43    39    34    46    29

# %%
# Örnek:

df3[(df3["VAL1"]> 30) & (df3["VAL5"]<40)]
# Out:
#    VAL1  VAL2  VAL3  VAL4  VAL5
# A    41    21    27    16    33
# J    43    39    34    46    29

# %%
df3[(df3["VAL1"]> 30) & (df3["VAL5"]<40)][["VAL1","VAL5"]]
# Out:
#    VAL1  VAL5
# A    41    33
# J    43    29

# %%
df3
# Out:
#    VAL1  VAL2  VAL3  VAL4  VAL5
# A    41    21    27    16    33
# B    21    19    23    14    38
# C    10    15    22    39    29
# D    18    39    44    18    29
# E    20    22    41    33    10
# F    19    18    46    29    45
# G    38    17    20    49    48
# H    19    28    17    49    25
# I    10    22    27    21    25
# J    43    39    34    46    29

# %%
# Örnek :

df3[(df3["VAL1"]>= 18) & (df3["VAL2"]<= 20) & (df3["VAL3"]>=20)]
# Out:
#    VAL1  VAL2  VAL3  VAL4  VAL5
# B    21    19    23    14    38
# F    19    18    46    29    45
# G    38    17    20    49    48

# %%
df3[(df3["VAL1"]>= 18) & (df3["VAL2"]<= 20) & (df3["VAL3"]>=20)][["VAL1","VAL2","VAL3"]]
# Out:
#    VAL1  VAL2  VAL3
# B    21    19    23
# F    19    18    46
# G    38    17    20

# %%
df3
# Out:
#    VAL1  VAL2  VAL3  VAL4  VAL5
# A    41    21    27    16    33
# B    21    19    23    14    38
# C    10    15    22    39    29
# D    18    39    44    18    29
# E    20    22    41    33    10
# F    19    18    46    29    45
# G    38    17    20    49    48
# H    19    28    17    49    25
# I    10    22    27    21    25
# J    43    39    34    46    29

# %%
# Örnek :

# %% [markdown]
# **Örnek Soru:**
#
# **df3 < 35 or "VAL5" < 20**

# %%
df3[(df3<35) | (df3["VAL5"]<20)]
# Out:
#    VAL1  VAL2  VAL3  VAL4  VAL5
# A   NaN  21.0  27.0  16.0  33.0
# B  21.0  19.0  23.0  14.0   NaN
# C  10.0  15.0  22.0   NaN  29.0
# D  18.0   NaN   NaN  18.0  29.0
# E  20.0  22.0   NaN  33.0  10.0
# F  19.0  18.0   NaN  29.0   NaN
# G   NaN  17.0  20.0   NaN   NaN
# H  19.0  28.0  17.0   NaN  25.0
# I  10.0  22.0  27.0  21.0  25.0
# J   NaN   NaN  34.0   NaN  29.0

# %% [markdown]
# ### loc[] Yapısı ile Koşullu İşlemler

# %%
df3
# Out:
#    VAL1  VAL2  VAL3  VAL4  VAL5
# A    41    21    27    16    33
# B    21    19    23    14    38
# C    10    15    22    39    29
# D    18    39    44    18    29
# E    20    22    41    33    10
# F    19    18    46    29    45
# G    38    17    20    49    48
# H    19    28    17    49    25
# I    10    22    27    21    25
# J    43    39    34    46    29

# %%
df3.loc[df3.VAL2> 20,["VAL2","VAL3","VAL5"]]
# Out:
#    VAL2  VAL3  VAL5
# A    21    27    33
# D    39    44    29
# E    22    41    10
# H    28    17    25
# I    22    27    25
# J    39    34    29

# %%
df3.loc[df3.VAL1 | df3.VAL2 >30,["VAL1","VAL2"]]
# Out:
#    VAL1  VAL2
# A    41    21
# D    18    39
# G    38    17
# H    19    28
# J    43    39
